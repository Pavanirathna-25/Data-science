# %% [markdown]
# Q1. Find a account code for banking case 1; use sample reference ACC-1001 and explain the result.

# %%
import re
account_code = "ACC-1001"
pattern = r"^ACC-\d{4}$"
if re.match(pattern, account_code):
    print("Valid account code:", account_code)
else:
    print("Invalid account code")
# Out:
# Valid account code: ACC-1001

# %% [markdown]
# Q2. Validate a six-digit pin for banking case 1; use sample reference ACC-1002 and explain the result.

# %%
import re
pin = "123456"
pattern = r"^\d{6}$"
if re.match(pattern, pin):
    print("Valid six-digit PIN")
else:
    print("Invalid PIN")
# Out:
# Valid six-digit PIN

# %% [markdown]
# Q3. Extract all amounts for banking case 1; use sample reference ACC-1003 and explain the result.

# %%
import re
text = "Deposited ₹5000, withdrew ₹1500 and transferred ₹2500."
pattern = r"₹\d+"
amounts = re.findall(pattern, text)
print("Amounts found:", amounts)
# Out:
# Amounts found: ['₹5000', '₹1500', '₹2500']

# %% [markdown]
# Q4. Match a receipt date for banking case 1; use sample reference ACC-1004 and explain the result.

# %%
import re
receipt = "Payment received on 06-09-2026."
pattern = r"\b\d{2}-\d{2}-\d{4}\b"
match = re.search(pattern, receipt)
if match:
    print("Receipt date found:", match.group())
else:
    print("Receipt date not found")
# Out:
# Receipt date found: 06-09-2026

# %% [markdown]
# Q5. Find uppercase account references for banking case 1; use sample reference ACC-1005 and explain the result.

# %%
import re
text = "Accounts used are ACC-1005, acc-1006 and ACC-1007."
pattern = r"\bACC-\d{4}\b"
references = re.findall(pattern, text)
print("Uppercase account references:", references)
# Out:
# Uppercase account references: ['ACC-1005', 'ACC-1007']

# %% [markdown]
# Q6. Remove extra spaces for banking case 1; use sample reference ACC-1006 and explain the result.

# %%
import re
text = "Account   ACC-1006   received   payment   successfully."
pattern = r"\s+"
clean_text = re.sub(pattern, " ", text)
print("Original text:", text)
print("Cleaned text:", clean_text)
# Out:
# Original text: Account   ACC-1006   received   payment   successfully.
# Cleaned text: Account ACC-1006 received payment successfully.

# %% [markdown]
# Q7. Split a comma-separated tag list for banking case 1; use sample reference ACC-1007 and explain the result.

# %%
tags = "savings,verified,active,online-banking"
tag_list = tags.split(",")
print("Original tags:", tags)
print("Split tags:", tag_list)
# Out:
# Original tags: savings,verified,active,online-banking
# Split tags: ['savings', 'verified', 'active', 'online-banking']

# %% [markdown]
# Q8. Check a phone number for banking case 1; use sample reference ACC-1008 and explain the result.

# %%
import re
phone = "9876543210"
pattern = r"^\d{10}$"
if re.match(pattern, phone):
    print("Valid phone number")
else:
    print("Invalid phone number")
# Out:
# Valid phone number

# %% [markdown]
# Q9. Find fee waiver codes for banking case 1; use sample reference ACC-1009 and explain the result.

# %%
import re
text = "Applied FEE-WAIVER-10 and FEE-WAIVER-20 for eligible accounts."
pattern = r"\bFEE-WAIVER-\d+\b"
codes = re.findall(pattern, text)
print("Fee waiver codes:", codes)
# Out:
# Fee waiver codes: ['FEE-WAIVER-10', 'FEE-WAIVER-20']

# %% [markdown]
# Q10. Replace masked card digits for banking case 1; use sample reference ACC-1010 and explain the result.

# %%
import re
card = "Card number: 1234-****-****-5678"
pattern = r"\d{4}(?=-\*{4}-\*{4}-\d{4})"
masked_card = re.sub(pattern, "****", card)
print("Original:", card)
print("Updated:", masked_card)
# Out:
# Original: Card number: 1234-****-****-5678
# Updated: Card number: ****-****-****-5678

# %% [markdown]
# Q11. Extract quantities for banking case 1; use sample reference ACC-1011 and explain the result.

# %%
import re
text = "Account ACC-1011 received 250 units and transferred 75 units."
pattern = r"\b\d+\b"
quantities = re.findall(pattern, text)
print("Quantities:", quantities)
# Out:
# Quantities: ['1011', '250', '75']

# %% [markdown]
# Q12. Match branch ids for banking case 1; use sample reference ACC-1012 and explain the result.

# %%
import re
text = "Account ACC-1012 is linked to branches BR1001 and BR2050."
pattern = r"\bBR\d{4}\b"
branch_ids = re.findall(pattern, text)
print("Branch IDs:", branch_ids)
# Out:
# Branch IDs: ['BR1001', 'BR2050']

# %% [markdown]
# Q13. Find email addresses for banking case 1; use sample reference ACC-1013 and explain the result.

# %%
import re
text = "Customer ACC-1013 can be contacted at customer@gmail.com or support@bank.com."
pattern = r"\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}\b"
emails = re.findall(pattern, text)
print("Email addresses:", emails)
# Out:
# Email addresses: ['customer@gmail.com', 'support@bank.com']

# %% [markdown]
# Q14. Validate a postcode for banking case 1; use sample reference ACC-1014 and explain the result.

# %%
import re
postcode = "560001"
pattern = r"^\d{6}$"
if re.match(pattern, postcode):
    print("Valid postcode")
else:
    print("Invalid postcode")
# Out:
# Valid postcode

# %% [markdown]
# Q15. Detect the word sale for banking case 1; use sample reference ACC-1015 and explain the result.

# %%
import re
text = "Account ACC-1015 has a special sale offer."
pattern = r"\bsale\b"
if re.search(pattern, text, re.IGNORECASE):
    print("The word 'sale' was found")
else:
    print("The word 'sale' was not found")
# Out:
# The word 'sale' was found

# %% [markdown]
# Q16. Find a account code for banking case 2; use sample reference ACC-1016 and explain the result.

# %%
import re
text = "The customer account reference is ACC-1016."
pattern = r"\bACC-\d{4}\b"
account_code = re.search(pattern, text)
if account_code:
    print("Account code found:", account_code.group())
else:
    print("Account code not found")
# Out:
# Account code found: ACC-1016

# %% [markdown]
# Q17. Validate a six-digit pin for banking case 2; use sample reference ACC-1017 and explain the result.

# %%
import re
pin = "654321"
pattern = r"^\d{6}$"
if re.match(pattern, pin):
    print("Valid six-digit PIN")
else:
    print("Invalid PIN")
# Out:
# Valid six-digit PIN

# %% [markdown]
# Q18. Extract all amounts for banking case 2; use sample reference ACC-1018 and explain the result.

# %%
import re
text = "ACC-1018: Deposited ₹25,000.50, paid ₹3,500 and received ₹1,250.75."
pattern = r"\b\d{1,3}(?:,\d{3})*(?:\.\d{2})?\b"
amounts = re.findall(pattern, text)
print("Extracted amounts:", amounts)
# Out:
# Extracted amounts: ['25,000.50', '3,500', '1,250.75']

# %% [markdown]
# Q19. Match a receipt date for banking case 2; use sample reference ACC-1019 and explain the result.

# %%
import re
text = "ACC-1019 receipts were generated on 15/08/2026 and 28/08/2026."
pattern = r"\b\d{2}/\d{2}/\d{4}\b"
dates = re.findall(pattern, text)
print("Receipt dates found:", dates)
# Out:
# Receipt dates found: ['15/08/2026', '28/08/2026']

# %% [markdown]
# Q20. Find uppercase account references for banking case 2; use sample reference ACC-1020 and explain the result.

# %%
import re
text = "Banking records: ACC-1020, ACC-2025 and acc-3030."
pattern = r"\bACC-[0-9]{4}\b"
matches = re.finditer(pattern, text)
for match in matches:
    print("Account reference:", match.group())
    print("Position:", match.start())
# Out:
# Account reference: ACC-1020
# Position: 17
# Account reference: ACC-2025
# Position: 27

# %% [markdown]
# Q21. Remove extra spaces for banking case 2; use sample reference ACC-1021 and explain the result.

# %%
text = "   Account    ACC-1021    has    a    balance.   "
clean_text = " ".join(text.split())
print("Original:", text)
print("Cleaned:", clean_text)
# Out:
# Original:    Account    ACC-1021    has    a    balance.
# Cleaned: Account ACC-1021 has a balance.

# %% [markdown]
# Q22. Split a comma-separated tag list for banking case 2; use sample reference ACC-1022 and explain the result

# %%
import re
text = "savings, verified, premium, online-banking"
pattern = r"\s*,\s*"
tags = re.split(pattern, text)
print("Tags:", tags)
# Out:
# Tags: ['savings', 'verified', 'premium', 'online-banking']

# %% [markdown]
# Q23. Check a phone number for banking case 2; use sample reference ACC-1023 and explain the result.

# %%
import re
phone = "9876543210"
pattern = r"[6-9]\d{9}"
if re.fullmatch(pattern, phone):
    print("Valid Indian phone number")
else:
    print("Invalid phone number")
# Out:
# Valid Indian phone number

# %% [markdown]
# Q24. Find fee waiver codes for banking case 2; use sample reference ACC-1024 and explain the result.

# %%
import re
text = "ACC-1024 received codes WAIVER10, WAIVER25 and BONUS50."
pattern = r"\bWAIVER\d{2}\b"
matches = re.finditer(pattern, text)
for match in matches:
    print("Fee waiver code:", match.group())
    print("Position:", match.start())
# Out:
# Fee waiver code: WAIVER10
# Position: 24
# Fee waiver code: WAIVER25
# Position: 34

# %% [markdown]
# Q25. Replace masked card digits for banking case 2; use sample reference ACC-1025 and explain the result.

# %%
import re
text = "ACC-1025 card number is 4567-1234-5678-9012."
pattern = r"(?<=\d{4}-)\d{4}-\d{4}(?=-\d{4})"
masked_card = re.sub(pattern, "****-****", text)
print("Original:", text)
print("Masked:", masked_card)
# Out:
# Original: ACC-1025 card number is 4567-1234-5678-9012.
# Masked: ACC-1025 card number is 4567-****-****-9012.

# %% [markdown]
# Q26. Extract quantities for banking case 2; use sample reference ACC-1026 and explain the result.

# %%
import re
text = "ACC-1026 processed 150 transactions and 25 deposits."
pattern = r"\b\d+\s+(?:transactions|deposits)\b"
matches = re.finditer(pattern, text)
for match in matches:
    print("Quantity found:", match.group())
# Out:
# Quantity found: 150 transactions
# Quantity found: 25 deposits

# %% [markdown]
# Q27. Match branch ids for banking case 2; use sample reference ACC-1027 and explain the result.

# %%
import re
text = "BR3050 - ACC-1027 branch transaction"
pattern = r"BR\d{4}"
match = re.match(pattern, text)
if match:
    print("Branch ID found:", match.group())
else:
    print("Branch ID not found")
# Out:
# Branch ID found: BR3050

# %% [markdown]
# Q28. Find email addresses for banking case 2; use sample reference ACC-1028 and explain the result.

# %%
import re
text = "ACC-1028 contact details: pavani@bank.in and support@finance.com."
pattern = r"[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}"
matches = re.finditer(pattern, text)
for match in matches:
    print("Email found:", match.group())
# Out:
# Email found: pavani@bank.in
# Email found: support@finance.com

# %% [markdown]
# Q29. Validate a postcode for banking case 2; use sample reference ACC-1029 and explain the result.

# %%
import re
postcode = "500032"
pattern = r"[1-9]\d{5}"
if re.fullmatch(pattern, postcode):
    print("Valid Indian postcode")
else:
    print("Invalid postcode")
# Out:
# Valid Indian postcode

# %% [markdown]
# Q30. Detect the word sale for banking case 2; use sample reference ACC-1030 and explain the result.

# %%
import re
text = "ACC-1030 has a sale offer. The sale is available today."
pattern = r"\bsale\b"
matches = re.findall(pattern, text, re.IGNORECASE)
if matches:
    print("Word 'sale' found:", len(matches), "time(s)")
else:
    print("Word 'sale' not found")
# Out:
# Word 'sale' found: 2 time(s)

# %% [markdown]
# Q31. Parse a receipt line into named groups for banking case 1; use sample reference ACC-1031 and explain the result.

# %%
import re
receipt = "ACC-1031 | Date: 06-09-2026 | Amount: ₹7500"
pattern = (
    r"(?P<account>ACC-\d{4})\s*\|\s*"
    r"Date:\s*(?P<date>\d{2}-\d{2}-\d{4})\s*\|\s*"
    r"Amount:\s*₹(?P<amount>\d+)"
)
match = re.search(pattern, receipt)
if match:
    print("Account:", match.group("account"))
    print("Date:", match.group("date"))
    print("Amount:", match.group("amount"))
else:
    print("Receipt format not matched")
# Out:
# Account: ACC-1031
# Date: 06-09-2026
# Amount: 7500

# %% [markdown]
# Q32. Validate an account reference with optional category prefix for banking case 1; use sample reference ACC-1032 and explain the result.

# %%
import re
account = "SAV-ACC-1032"
pattern = r"^(?:SAV|CUR|SAL-)?-?ACC-\d{4}$"
if re.fullmatch(pattern, account):
    print("Valid account reference")
else:
    print("Invalid account reference")
# Out:
# Valid account reference

# %% [markdown]
# Q33. Extract currency and amount for banking case 1; use sample reference ACC-1033 and explain the result.

# %%
import re
text = "ACC-1033 received ₹15,750.50."
pattern = r"(?P<currency>[₹$€£])\s*(?P<amount>[\d,]+(?:\.\d{2})?)"
match = re.search(pattern, text)
if match:
    print("Currency:", match.group("currency"))
    print("Amount:", match.group("amount"))
else:
    print("Currency and amount not found")
# Out:
# Currency: ₹
# Amount: 15,750.50

# %% [markdown]
# Q34. Normalize account holder phone numbers for banking case 1; use sample reference ACC-1034 and explain the result.

# %%
import re
phone = "+91 98765-43210"
cleaned = re.sub(r"\D", "", phone)
if cleaned.startswith("91") and len(cleaned) == 12:
    cleaned = cleaned[2:]
print("Original phone:", phone)
print("Normalized phone:", cleaned)
# Out:
# Original phone: +91 98765-43210
# Normalized phone: 9876543210

# %% [markdown]
# Q35. Find repeated account words for banking case 1; use sample reference ACC-1035 and explain the result.

# %%
import re
text = "ACC-1035 account account is active and verified."
pattern = r"\b(\w+)\s+\1\b"
match = re.search(pattern, text, re.IGNORECASE)
if match:
    print("Repeated word:", match.group(1))
else:
    print("No repeated word found")
# Out:
# Repeated word: account

# %% [markdown]
# Q36. Validate fee waiver start and end anchors for banking case 1; use sample reference ACC-1036 and explain the result.

# %%
import re
fee_code = "WAIVER-1036"
pattern = r"^WAIVER-\d{4}$"
if re.fullmatch(pattern, fee_code):
    print("Valid fee waiver code")
else:
    print("Invalid fee waiver code")
# Out:
# Valid fee waiver code

# %% [markdown]
# Q37. Redact emails from support text for banking case 1; use sample reference ACC-1037 and explain the result.

# %%
import re
support_text = """
Customer ACC-1037 contacted support through pavani@gmail.com.
For further help, email support@bank.com.
"""
pattern = r"\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}\b"
redacted_text = re.sub(pattern, "[REDACTED]", support_text)
print(redacted_text)
# Out:
# Customer ACC-1037 contacted support through [REDACTED].
# For further help, email [REDACTED].

# %% [markdown]
# Q38. Extract transfer ids without partial matches for banking case 1; use sample reference ACC-1038 and explain the result.

# %%
import re
text = """
Transfer TRF-1038 was completed.
Reference TRF-2045 is also valid.
Invalid reference XTRF-3099 should not be matched.
"""
pattern = r"\bTRF-\d{4}\b"
transfer_ids = re.findall(pattern, text)
print(transfer_ids)
# Out:
# ['TRF-1038', 'TRF-2045']

# %% [markdown]
# Q39. Parse inventory key-value pairs for banking case 1; use sample reference ACC-1039 and explain the result.

# %%
import re
inventory = """
Account=ACC-1039, Balance=25000, Status=Active, Branch=Bangalore
"""
pattern = r"(\w+)=([^,\s]+)"
pairs = re.findall(pattern, inventory)
print(pairs)
# Out:
# [('Account', 'ACC-1039'), ('Balance', '25000'), ('Status', 'Active'), ('Branch', 'Bangalore')]

# %% [markdown]
# Q40. Use lookahead for strong fee waiver tokens for banking case 1; use sample reference ACC-1040 and explain the result.

# %%
import re
text = """
ACC-1040 has WAIVER-1040-APPROVED.
Another token is WAIVER-2050-PENDING.
"""
pattern = r"\bWAIVER-\d{4}(?=-APPROVED\b)"
strong_tokens = re.findall(pattern, text)
print(strong_tokens)
# Out:
# ['WAIVER-1040']

# %% [markdown]
# Q41. Use negative lookahead to reject test account references for banking case 1; use sample reference ACC-1041 and explain the result.

# %%
import re
text = """
Valid account: ACC-1041
Test account: ACC-1042-TEST
Another valid account: ACC-1043
"""
pattern = r"\bACC-\d{4}\b(?!-TEST\b)"
valid_accounts = re.findall(pattern, text)
print(valid_accounts)
# Out:
# ['ACC-1041', 'ACC-1043']

# %% [markdown]
# Q42. Extract account names between delimiters for banking case 1; use sample reference ACC-1042 and explain the result.

# %%
import re
text = """
Accounts: [Savings Account], [Current Account], [Salary Account]
Reference: ACC-1042
"""
pattern = r"\[([^\]]+)\]"
account_names = re.findall(pattern, text)
print(account_names)
# Out:
# ['Savings Account', 'Current Account', 'Salary Account']

# %% [markdown]
# Q43. Replace dates with iso format for banking case 1; use sample reference ACC-1043 and explain the result.

# %%
import re
text = """
Account ACC-1043 was opened on 06-09-2026.
Last transaction was on 15-08-2026.
"""
pattern = r"\b(\d{2})-(\d{2})-(\d{4})\b"
def convert_date(match):
    day, month, year = match.groups()
    return f"{year}-{month}-{day}"
updated_text = re.sub(pattern, convert_date, text)
print(updated_text)
# Out:
# Account ACC-1043 was opened on 2026-09-06.
# Last transaction was on 2026-08-15.

# %% [markdown]
# Q44. Compile a reusable account pattern for banking case 1; use sample reference ACC-1044 and explain the result.

# %%
import re
account_pattern = re.compile(r"\bACC-\d{4}\b")
text = """
Primary account: ACC-1044
Linked account: ACC-2050
Old account: ACC-3099
"""
accounts = account_pattern.findall(text)
print(accounts)
# Out:
# ['ACC-1044', 'ACC-2050', 'ACC-3099']

# %% [markdown]
# Q45. Use case-insensitive matching for brand search for banking case 1; use sample reference ACC-1045 and explain the result.

# %%
import re
text = """
ACC-1045 purchased from HDFC Bank.
Another transaction was made through hdfc bank.
"""
pattern = r"\bhdfc bank\b"
matches = re.findall(pattern, text, re.IGNORECASE)
print(matches)
# Out:
# ['HDFC Bank', 'hdfc bank']

# %% [markdown]
# Q46. Parse a receipt line into named groups for banking case 2; use sample reference ACC-1046 and explain the result.

# %%
import re
receipt = "ACC-1046 | 06-09-2026 | ₹5000"
pattern = r"(ACC-\d{4}) \| (\d{2}-\d{2}-\d{4}) \| ₹(\d+)"
match = re.search(pattern, receipt)
if match:
    account, date, amount = match.groups()
    print("Account:", account)
    print("Date:", date)
    print("Amount:", amount)
# Out:
# Account: ACC-1046
# Date: 06-09-2026
# Amount: 5000

# %% [markdown]
# Q47. Validate an account reference with optional category prefix for banking case 2; use sample reference ACC-1047 and explain the result.

# %%
import re
account = "SAV-ACC-1047"
pattern = r"(?:SAV-|CUR-|SAL-)?ACC-\d{4}(?=\s|$)"
if re.search(pattern, account):
    print("Valid account reference")
else:
    print("Invalid account reference")
# Out:
# Valid account reference

# %% [markdown]
# Q48. Extract currency and amount for banking case 2; use sample reference ACC-1048 and explain the result.

# %%
import re

text = "ACC-1048 received ₹12,500 and paid $300."

pattern = r"([₹$€£])\s*([\d,]+(?:\.\d+)?)"

for match in re.finditer(pattern, text):
    currency = match.group(1)
    amount = match.group(2)
    print("Currency:", currency)
    print("Amount:", amount)
# Out:
# Currency: ₹
# Amount: 12,500
# Currency: $
# Amount: 300

# %% [markdown]
# Q49. Normalize account holder phone numbers for banking case 2; use sample reference ACC-1049 and explain the result.

# %%
import re
phone = "+91 98765-43210"
parts = re.findall(r"\d+", phone)
number = "".join(parts)
if number.startswith("91") and len(number) == 12:
    number = number[2:]
print("Normalized phone number:", number)
# Out:
# Normalized phone number: 9876543210

# %% [markdown]
# ### Q50. Find repeated account words for banking case 2; use sample reference `ACC-1050` and explain the result.

# %%
text = "ACC-1050 account is active and the account is verified."
words = text.lower().split()
repeated_words = []
for word in set(words):
    if words.count(word) > 1:
        repeated_words.append(word)
print("Repeated words:", repeated_words)
# Out:
# Repeated words: ['is', 'account']

# %% [markdown]
# Q51. Create insufficientfundserror for banking case 3; use sample reference ACC-1051 and explain the result.

# %%
import re
class InsufficientFundsError(Exception):
    pass
reference = "ACC-1051"
balance = 5000
withdraw = 7000
if re.match(r"^\d+$", str(withdraw)):
    if withdraw > balance:
      raise InsufficientFundsError(
            f"{reference}: Insufficient funds"
        )
    else:
        print("Transaction successful")
# Out:
# ---------------------------------------------------------------------------
# InsufficientFundsError                    Traceback (most recent call last)
# /tmp/ipykernel_659/777515470.py in <cell line: 0>()
#       7 if re.match(r"^\d+$", str(withdraw)):
#       8     if withdraw > balance:
# ----> 9       raise InsufficientFundsError(
#      10             f"{reference}: Insufficient funds"
#      11         )
#
# InsufficientFundsError: ACC-1051: Insufficient funds

# %% [markdown]
# Q52. Chain invalidtransactionerror from valueerror for banking case 3; use sample reference ACC-1052 and explain the result.

# %%
import re
class InvalidTransactionError(Exception):
  pass
reference = "ACC-1052"
try:
  amount = "abcd"
  if not re.match(r"^\d+$", amount):
    raise ValueError("Invalid Amount")
except ValueError as e:
  raise InvalidTransactionError(f"{reference}: {e}")

# %% [markdown]
# Q53. Process transfers while isolating bad rows for banking case 3; use sample reference ACC-1053 and explain the result.

# %%
import re
class InvalidTransactionError(Exception):
    pass
reference = "ACC-1053"
transfers = ["1000", "2000", "abc", "3000"]
for amount in transfers:
    try:
        if not re.match(r"^\d+$", amount):
            raise ValueError("Invalid amount")
        print(f"{reference}: Transfer of ₹{amount} processed")
    except ValueError:
        print(f"{reference}: Bad row skipped - {amount}")
# Out:
# ACC-1053: Transfer of ₹1000 processed
# ACC-1053: Transfer of ₹2000 processed
# ACC-1053: Bad row skipped - abc
# ACC-1053: Transfer of ₹3000 processed

# %% [markdown]
# Q54. Retry a transient payment gateway for banking case 3; use sample reference ACC-1054 and explain the result.

# %%
import re
reference = "ACC-1054"
attempts = 0
while attempts < 3:
    try:
        attempts += 1
        payment = "1000"
        if not re.match(r"^\d+$", payment):
            raise ValueError("Invalid payment")
        if attempts < 3:
            raise ConnectionError("Payment gateway temporarily unavailable")
        print(f"{reference}: Payment successful on attempt {attempts}")
    except ConnectionError:
        print(f"{reference}: Gateway failed, retrying...")
# Out:
# ACC-1054: Gateway failed, retrying...
# ACC-1054: Gateway failed, retrying...
# ACC-1054: Payment successful on attempt 3

# %% [markdown]
# Q55. Log failed standing instructions for banking case 3; use sample reference ACC-1055 and explain the result.

# %%
import re
reference = "ACC-1055"
amount = "5000"
balance = 3000
try:
    if not re.match(r"^\d+$", amount):
        raise ValueError("Invalid amount")
    if int(amount) > balance:
        raise ValueError("Insufficient funds")
    print(f"{reference}: Standing instruction successful")
except ValueError as e:
    print(f"{reference}: Standing instruction failed - {e}")
# Out:
# ACC-1055: Standing instruction failed - Insufficient funds

# %% [markdown]
# Q56. Return a structured failure result for banking case 3; use sample reference ACC-1056 and explain the result.

# %%
import re
reference = "ACC-1056"
amount = "5000"
balance = 3000
try:
    if not re.match(r"^\d+$", amount):
        raise ValueError("Invalid amount")
    if int(amount) > balance:
        raise ValueError("Insufficient funds")
    result = {
        "reference": reference,
        "status": "success",
        "message": "Transaction successful"
    }
except ValueError as e:
    result = {
        "reference": reference,
        "status": "failed",
        "message": str(e)
    }
print(result)
# Out:
# {'reference': 'ACC-1056', 'status': 'failed', 'message': 'Insufficient funds'}

# %% [markdown]
# Q57. Validate a nested beneficiary record for banking case 3; use sample reference ACC-1057 and explain the result.

# %%
import re
reference = "ACC-1057"
beneficiary = {
    "name": "Ravi",
    "account": {
        "number": "1234567890",
        "ifsc": "SBIN0001234"
    }
}
if (re.match(r"^[A-Za-z ]+$", beneficiary["name"]) and
    re.match(r"^\d{10}$", beneficiary["account"]["number"]) and
    re.match(r"^[A-Z]{4}0[A-Z0-9]{6}$", beneficiary["account"]["ifsc"])):
    result = {
        "reference": reference,
        "status": "valid",
        "message": "Beneficiary record is valid"
    }
else:
    result = {
        "reference": reference,
        "status": "failed",
        "message": "Invalid beneficiary record"
    }

print(result)
# Out:
# {'reference': 'ACC-1057', 'status': 'valid', 'message': 'Beneficiary record is valid'}

# %% [markdown]
# Q58. Use a context manager for an audit file for banking case 3; use sample reference ACC-1058 and explain the result.

# %%
import re
reference = "ACC-1058"
amount = "5000"
with open("audit.txt", "w") as file:
    if re.match(r"^\d+$", amount):
        file.write(f"{reference}: Transaction successful\n")
    else:
        file.write(f"{reference}: Transaction failed\n")
print("Audit record saved")
# Out:
# Audit record saved

# %% [markdown]
# Q59. Separate validation and recovery for banking case 3; use sample reference ACC-1059 and explain the result.

# %%
import re
reference = "ACC-1059"
amount = "abc"
try:
    if not re.match(r"^\d+$", amount):
        raise ValueError("Invalid amount")
    print(f"{reference}: Validation successful")
except ValueError as e:
    print(f"{reference}: Recovery - {e}")
    print("Transaction rejected safely")
# Out:
# ACC-1059: Recovery - Invalid amount
# Transaction rejected safely

# %% [markdown]
# Q60. Collect all kyc validation errors for banking case 3; use sample reference ACC-1060 and explain the result.

# %%
import re
reference = "ACC-1060"
def validate_kyc(kyc):
    errors = []
    if not re.match(r"^[A-Za-z ]+$", kyc["name"]):
        errors.append("Invalid name")
    if not re.match(r"^[A-Z]{5}[0-9]{4}[A-Z]$", kyc["pan"]):
        errors.append("Invalid PAN")
    if not re.match(r"^\d{10}$", kyc["phone"]):
        errors.append("Invalid phone number")
    return errors
kyc = {
    "name": "Ravi123",
    "pan": "12345",
    "phone": "98765"
}
errors = validate_kyc(kyc)
print({
    "reference": reference,
    "status": "failed" if errors else "valid",
    "errors": errors
})
# Out:
# {'reference': 'ACC-1060', 'status': 'failed', 'errors': ['Invalid name', 'Invalid PAN', 'Invalid phone number']}

# %% [markdown]
# Q61. Create insufficientfundserror for banking case 4; use sample reference ACC-1061 and explain the result.

# %%
import re
class Insufficientfundserror(Exception):
  pass
reference = "ACC-1061"
amount = 1000
withdraw = 5000
if re.match(r"^\d+$",str(withdraw)):
  if withdraw > amount:
    raise Insufficientfundserror(f"{reference}: Insufficientfundserror")
  else:
    print("Transaction is Success")
# Out:
# ---------------------------------------------------------------------------
# Insufficientfundserror                    Traceback (most recent call last)
# /tmp/ipykernel_659/3315964220.py in <cell line: 0>()
#       7 if re.match(r"^\d+$",str(withdraw)):
#       8   if withdraw > amount:
# ----> 9     raise Insufficientfundserror(f"{reference}: Insufficientfundserror")
#      10   else:
#      11     print("Transaction is Success")
#
# Insufficientfundserror: ACC-1061: Insufficientfundserror

# %% [markdown]
# Q62. Chain invalidtransactionerror from valueerror for banking case 4; use sample reference ACC-1062 and explain the result.

# %%
import re
class InvalidTransactionError(Exception):
    pass
reference = "ACC-1062"
amount = "abc"
try:
    if not re.match(r"^\d+$", amount):
        raise ValueError("Invalid amount")
except ValueError as e:
    print(f"{reference}: ValueError - {e}")
    print(f"{reference}: InvalidTransactionError - Invalid transaction")

# %% [markdown]
# Q63. Process transfers while isolating bad rows for banking case 4; use sample reference ACC-1063 and explain the result.

# %%
import re
reference = "ACC-1063"
transfers = ["1000", "2000", "abc", "3000"]
for amount in transfers:
    try:
        if not re.match(r"^\d+$", amount):
            raise ValueError("Invalid amount")
        print(f"{reference}: Transfer of ₹{amount} processed")
    except ValueError:
        print(f"{reference}: Bad row skipped - {amount}")

# %% [markdown]
# Q64. Retry a transient payment gateway for banking case 4; use sample reference ACC-1064 and explain the result.

# %%
import re
reference = "ACC-1064"
def retry_payment(attempt):
    payment = "1000"
    if not re.match(r"^\d+$", payment):
        print(f"{reference}: Invalid payment")
        return
    if attempt < 3:
        print(f"{reference}: Gateway failed on attempt {attempt}")
        return retry_payment(attempt + 1)
    print(f"{reference}: Payment successful on attempt {attempt}")
retry_payment(1)

# %% [markdown]
# Q65. Log failed standing instructions for banking case 4; use sample reference ACC-1065 and explain the result.

# %%
import re
reference = "ACC-1065"
amount = "5000"
balance = 3000
log = {
    "reference": reference,
    "status": "success",
    "message": "Standing instruction successful"
}
if not re.match(r"^\d+$", amount):
    log["status"] = "failed"
    log["message"] = "Invalid amount"
elif int(amount) > balance:
    log["status"] = "failed"
    log["message"] = "Insufficient funds"
print(log)

# %% [markdown]
# Q66. Return a structured failure result for banking case 4; use sample reference ACC-1066 and explain the result.

# %%
import re
def check_transaction(reference, amount, balance):
    if not re.match(r"^\d+$", amount):
        return (reference, "failed", "Invalid amount")
    if int(amount) > balance:
        return (reference, "failed", "Insufficient funds")
    return (reference, "success", "Transaction successful")
result = check_transaction("ACC-1066", "5000", 3000)
print(result)
# Out:
# ('ACC-1066', 'failed', 'Insufficient funds')

# %% [markdown]
# Q67. Validate a nested beneficiary record for banking case 4; use sample reference ACC-1067 and explain the result.

# %%
import re
reference = "ACC-1067"
def validate_beneficiary(data):
    if not re.match(r"^[A-Za-z ]+$", data["name"]):
        return "Invalid name"
    if not re.match(r"^\d{10}$", data["account"]["number"]):
        return "Invalid account number"
    if not re.match(r"^[A-Z]{4}0[A-Z0-9]{6}$", data["account"]["ifsc"]):
        return "Invalid IFSC"
    return "Beneficiary record is valid"
result = validate_beneficiary({
    "name": "Ravi",
    "account": {
        "number": "1234567890",
        "ifsc": "SBIN0001234"
    }
})
print({
    "reference": reference,
    "status": "valid" if result == "Beneficiary record is valid" else "failed",
    "message": result
})
# Out:
# {'reference': 'ACC-1067', 'status': 'valid', 'message': 'Beneficiary record is valid'}

# %% [markdown]
# Q68. Use a context manager for an audit file for banking case 4; use sample reference ACC-1068 and explain the result.

# %%
import re
reference = "ACC-1068"
audit = {
    "reference": reference,
    "transaction": "Standing Instruction",
    "amount": 5000,
    "status": "Failed"
}
with open("bank_audit.txt", "w") as file:
    for key, value in audit.items():
        file.write(f"{key}: {value}\n")
print("Banking audit record created")
# Out:
# Banking audit record created

# %% [markdown]
# Q69. Separate validation and recovery for banking case 4; use sample reference ACC-1069 and explain the result.

# %%
import re
reference = "ACC-1069"
def validate(amount):
    return re.match(r"^\d+$", amount) is not None
def recover(amount):
    if not validate(amount):
        return {
            "reference": reference,
            "status": "failed",
            "message": "Invalid amount - transaction rejected"
        }
    return {
        "reference": reference,
        "status": "success",
        "message": "Transaction processed"
    }
result = recover("abc")
print(result)
# Out:
# {'reference': 'ACC-1069', 'status': 'failed', 'message': 'Invalid amount - transaction rejected'}

# %% [markdown]
# Q70. Collect all kyc validation errors for banking case 4; use sample reference ACC-1070 and explain the result.

# %%
import re
reference = "ACC-1070"
kyc = {
    "name": "Ravi123",
    "pan": "12345",
    "phone": "98765"
}
patterns = {
    "name": r"^[A-Za-z ]+$",
    "pan": r"^[A-Z]{5}[0-9]{4}[A-Z]$",
    "phone": r"^\d{10}$"
}
errors = {}
for field in patterns:
    if not re.match(patterns[field], kyc[field]):
        errors[field] = "Invalid " + field
result = {
    "reference": reference,
    "status": "failed" if errors else "valid",
    "errors": errors
}
print(result)
# Out:
# {'reference': 'ACC-1070', 'status': 'failed', 'errors': {'name': 'Invalid name', 'pan': 'Invalid pan', 'phone': 'Invalid phone'}}

# %% [markdown]
# Q71. Design a banking exception hierarchy for banking case 1; use sample reference ACC-1071 and explain the result.

# %%
import re
class BankingError(Exception):
    pass
class InsufficientFundsError(BankingError):
    pass
class InvalidTransactionError(BankingError):
    pass
reference = "ACC-1071"
balance = 3000
amount = "5000"
try:
    if not re.match(r"^\d+$", amount):
        raise InvalidTransactionError(
            f"{reference}: Invalid transaction"
        )
    if int(amount) > balance:
        raise InsufficientFundsError(
            f"{reference}: Insufficient funds"
        )
    print(f"{reference}: Transaction successful")
except BankingError as e:
    print(e)
# Out:
# ACC-1071: Insufficient funds

# %% [markdown]
# Q72. Make a transfer rollback-safe for banking case 1; use sample reference ACC-1072 and explain the result.

# %%
import re
reference = "ACC-1072"
def transfer(sender, receiver, amount):
    original_sender = sender
    original_receiver = receiver
    try:
        if not re.match(r"^\d+$", amount):
            raise ValueError("Invalid amount")
        amount = int(amount)
        if amount > sender:
            raise ValueError("Insufficient funds")
        sender -= amount
        receiver += amount
        raise ValueError("Transfer failed")
    except ValueError as e:
        sender = original_sender
        receiver = original_receiver
        return sender, receiver, "Rollback successful"
result = transfer(5000, 2000, "3000")
print(reference, result)
# Out:
# ACC-1072 (5000, 2000, 'Rollback successful')

# %% [markdown]
# Q73. Preserve causes across service layers for banking case 1; use sample reference ACC-1073 and explain the result.

# %%
import re
class BankingError(Exception):
    pass
reference = "ACC-1073"
amount = "abc"
def payment_service(amount):
    if not re.match(r"^\d+$", amount):
        raise ValueError("Invalid payment amount")
    return "Payment successful"
def banking_service(amount):
    try:
        return payment_service(amount)
    except ValueError as e:
        raise BankingError(
            f"{reference}: Payment service failed"
        ) from e
try:
    banking_service(amount)
except BankingError as e:
    print("Banking Error:", e)
    print("Original Cause:", e.__cause__)
# Out:
# Banking Error: ACC-1073: Payment service failed
# Original Cause: Invalid payment amount

# %% [markdown]
# Q74. Implement bounded exponential retry for banking case 1; use sample reference ACC-1074 and explain the result.

# %%
import re
import time
reference = "ACC-1074"
payment = "1000"
max_retries = 3
for attempt in range(max_retries):
    try:
        if not re.match(r"^\d+$", payment):
            raise ValueError("Invalid payment")
        if attempt < 2:
            raise ConnectionError("Gateway temporarily unavailable")
        print(f"{reference}: Payment successful on attempt {attempt + 1}")
        break
    except ConnectionError:
        delay = 2 ** attempt
        print(f"{reference}: Attempt {attempt + 1} failed")
        print(f"Waiting {delay} seconds before retry")
        time.sleep(delay)
else:
    print(f"{reference}: Payment failed after {max_retries} attempts")
# Out:
# ACC-1074: Attempt 1 failed
# Waiting 1 seconds before retry
# ACC-1074: Attempt 2 failed
# Waiting 2 seconds before retry
# ACC-1074: Payment successful on attempt 3

# %% [markdown]
# Q75. Create a transaction context manager for banking case 1; use sample reference ACC-1075 and explain the result.

# %%
import re
class Transaction:
    def __init__(self, reference):
        self.reference = reference
    def __enter__(self):
        print(f"{self.reference}: Transaction started")
        return self
    def __exit__(self, exc_type, exc_value, traceback):
        if exc_type is None:
            print(f"{self.reference}: Transaction committed")
        else:
            print(f"{self.reference}: Transaction rolled back")
        return True
reference = "ACC-1075"
amount = "5000"
with Transaction(reference):
    if not re.match(r"^\d+$", amount):
        raise ValueError("Invalid amount")
    print(f"{reference}: Processing ₹{amount}")
print("Transaction completed")
# Out:
# ACC-1075: Transaction started
# ACC-1075: Processing ₹5000
# ACC-1075: Transaction committed
# Transaction completed

# %% [markdown]
# Q76. Build a dead-letter queue for payment events for banking case 1; use sample reference ACC-1076 and explain the result.

# %%
import re
reference = "ACC-1076"
payment_events = [
    {"id": "P101", "amount": "1000"},
    {"id": "P102", "amount": "abc"},
    {"id": "P103", "amount": "2500"}
]
dead_letter_queue = []
for event in payment_events:
    if re.match(r"^\d+$", event["amount"]):
        print(f"{reference}: Payment {event['id']} processed")
    else:
        dead_letter_queue.append(event)
        print(f"{reference}: Payment {event['id']} moved to DLQ")
print("Dead-Letter Queue:", dead_letter_queue)
# Out:
# ACC-1076: Payment P101 processed
# ACC-1076: Payment P102 moved to DLQ
# ACC-1076: Payment P103 processed
# Dead-Letter Queue: [{'id': 'P102', 'amount': 'abc'}]

# %% [markdown]
# Q77. Make batch settlement failure-isolated for banking case 1; use sample reference ACC-1077 and explain the result.

# %%
import re
reference = "ACC-1077"
settlements = {
    "S201": "1500",
    "S202": "wrong",
    "S203": "3000"
}
results = {}
for settlement_id, amount in settlements.items():
    if re.match(r"^\d+$", amount):
        results[settlement_id] = "successful"
    else:
        results[settlement_id] = "failed"
print({
    "reference": reference,
    "settlement_results": results
})
# Out:
# {'reference': 'ACC-1077', 'settlement_results': {'S201': 'successful', 'S202': 'failed', 'S203': 'successful'}}

# %% [markdown]
# Q78. Report exact paths in nested statements for banking case 1; use sample reference ACC-1078 and explain the result.

# %%
import re
reference = "ACC-1078"
data = {
    "customer": {
        "name": "Ravi",
        "account": {
            "number": "12345",
            "ifsc": "SBIN0001234"
        }
    }
}
paths = [
    ("customer.name", data["customer"]["name"], r"^[A-Za-z ]+$"),
    ("customer.account.number", data["customer"]["account"]["number"], r"^\d{10}$"),
    ("customer.account.ifsc", data["customer"]["account"]["ifsc"], r"^[A-Z]{4}0[A-Z0-9]{6}$")
]
for path, value, pattern in paths:
    if not re.match(pattern, value):
        print(f"{reference}: Invalid path - {path}")
# Out:
# ACC-1078: Invalid path - customer.account.number

# %% [markdown]
# Q79. Design idempotent recovery after timeout for banking case 1; use sample reference ACC-1079 and explain the result.

# %%
import re
reference = "ACC-1079"
amount = "5000"
processed = []
if re.match(r"^\d+$", amount):
    if reference not in processed:
        processed.append(reference)
        print(f"{reference}: Payment processed successfully")
    else:
        print(f"{reference}: Payment already processed")
if reference in processed:
    print(f"{reference}: Recovery skipped duplicate payment")
# Out:
# ACC-1079: Payment processed successfully
# ACC-1079: Recovery skipped duplicate payment

# %% [markdown]
# Q80. Build an exception-safe reconciliation pipeline for banking case 1; use sample reference ACC-1080 and explain the result.

# %%
import re
reference = "ACC-1080"
def reconcile(bank_amount, system_amount):
    if not re.match(r"^\d+$", bank_amount):
        return "Invalid record"
    if int(bank_amount) == system_amount:
        return "Matched"
    return "Mismatch"
records = [
    ("T201", "1500", 1500),
    ("T202", "3000", 3500),
    ("T203", "wrong", 1000)
]
for transaction_id, bank_amount, system_amount in records:
    try:
        result = reconcile(bank_amount, system_amount)
        print(f"{reference}: {transaction_id} - {result}")
    except Exception:
        print(f"{reference}: {transaction_id} - Reconciliation failed")
# Out:
# ACC-1080: T201 - Matched
# ACC-1080: T202 - Mismatch
# ACC-1080: T203 - Invalid record

# %% [markdown]
# Q81. Design a banking exception hierarchy for banking case 2; use sample reference ACC-1081 and explain the result.

# %%
import re
class BankingError(Exception):
    pass
class SecurityError(BankingError):
    pass
class OTPError(SecurityError):
    pass
class PINError(SecurityError):
    pass
reference = "ACC-1081"
otp = "12AB"
try:
    if not re.match(r"^\d{6}$", otp):
        raise OTPError(
            f"{reference}: Invalid OTP"
        )
    print(f"{reference}: OTP verified")
except SecurityError as error:
    print("Security Error:", error)
# Out:
# Security Error: ACC-1081: Invalid OTP

# %% [markdown]
# Q82. Make a transfer rollback-safe for banking case 2; use sample reference ACC-1082 and explain the result.

# %%
import re
reference = "ACC-1082"
sender = {"balance": 5000}
receiver = {"balance": 2000}
amount = "3000"
old_sender = sender["balance"]
old_receiver = receiver["balance"]
if re.match(r"^\d+$", amount):
    amount = int(amount)
    if amount <= sender["balance"]:
        sender["balance"] -= amount
        receiver["balance"] += amount
        success = False
        if not success:
            sender["balance"] = old_sender
            receiver["balance"] = old_receiver
            print(f"{reference}: Transfer failed and rolled back")
    else:
        print(f"{reference}: Insufficient funds")
else:
    print(f"{reference}: Invalid amount")
print("Sender:", sender["balance"])
print("Receiver:", receiver["balance"])
# Out:
# ACC-1082: Transfer failed and rolled back
# Sender: 5000
# Receiver: 2000

# %% [markdown]
# Q83. Preserve causes across service layers for banking case 2; use sample reference ACC-1083 and explain the result.

# %%
import re
class BankingError(Exception):
    pass
reference = "ACC-1083"
amount = "abc"
def account_service(amount):
    if not re.match(r"^\d+$", amount):
        raise ValueError("Invalid account amount")
    return "Account verified"
def payment_service(amount):
    try:
        return account_service(amount)
    except ValueError as error:
        raise BankingError(
            f"{reference}: Payment service failed"
        ) from error
try:
    payment_service(amount)
except BankingError as error:
    print("Banking Error:", error)
    print("Original Cause:", error.__cause__)
# Out:
# Banking Error: ACC-1083: Payment service failed
# Original Cause: Invalid account amount

# %% [markdown]
# Q84. Implement bounded exponential retry for banking case 2; use sample reference ACC-1084 and explain the result.

# %%
import re
reference = "ACC-1084"
payment = "2000"
def retry_payment(attempt, delay):
    if not re.match(r"^\d+$", payment):
        return "Invalid payment"
    if attempt == 3:
        return f"{reference}: Payment successful on attempt {attempt}"
    print(f"{reference}: Attempt {attempt} failed")
    print(f"Retry delay: {delay} seconds")
    return retry_payment(attempt + 1, delay * 2)
result = retry_payment(1, 1)
print(result)
# Out:
# ACC-1084: Attempt 1 failed
# Retry delay: 1 seconds
# ACC-1084: Attempt 2 failed
# Retry delay: 2 seconds
# ACC-1084: Payment successful on attempt 3

# %% [markdown]
# Q85. Create a transaction context manager for banking case 2; use sample reference ACC-1085 and explain the result.

# %%
import re
class BankTransaction:
    def __init__(self, reference):
        self.reference = reference
    def __enter__(self):
        print(f"{self.reference}: Transaction started")
        return self
    def __exit__(self, exc_type, exc_value, traceback):
        if exc_type:
            print(f"{self.reference}: Transaction failed and rolled back")
        else:
            print(f"{self.reference}: Transaction committed")
reference = "ACC-1085"
amount = "2500"
with BankTransaction(reference):
    if not re.match(r"^\d+$", amount):
        raise ValueError("Invalid amount")
    print(f"{reference}: Processing amount ₹{amount}")
print("Transaction finished")
# Out:
# ACC-1085: Transaction started
# ACC-1085: Processing amount ₹2500
# ACC-1085: Transaction committed
# Transaction finished

# %% [markdown]
# Q86. Build a dead-letter queue for payment events for banking case 2; use sample reference ACC-1086 and explain the result.

# %%
import re
reference = "ACC-1086"
payments = [
    {"id": "P201", "amount": "1500"},
    {"id": "P202", "amount": "wrong"},
    {"id": "P203", "amount": "3000"}
]
dead_letter_queue = []
for payment in payments:
    if re.match(r"^\d+$", payment["amount"]):
        print(f"{reference}: {payment['id']} processed successfully")
    else:
        dead_letter_queue.append(payment)
        print(f"{reference}: {payment['id']} moved to DLQ")
print("Dead-Letter Queue:", dead_letter_queue)
# Out:
# ACC-1086: P201 processed successfully
# ACC-1086: P202 moved to DLQ
# ACC-1086: P203 processed successfully
# Dead-Letter Queue: [{'id': 'P202', 'amount': 'wrong'}]

# %% [markdown]
# Q87. Make batch settlement failure-isolated for banking case 2; use sample reference ACC-1087 and explain the result.

# %%
import re
reference = "ACC-1087"
settlements = {
    "S301": "1800",
    "S302": "xyz",
    "S303": "2200"
}
results = {}
for settlement_id, amount in settlements.items():
    if re.match(r"^\d+$", amount):
        results[settlement_id] = "Success"
    else:
        results[settlement_id] = "Failed"
print(reference)
print("Settlement Results:", results)
# Out:
# ACC-1087
# Settlement Results: {'S301': 'Success', 'S302': 'Failed', 'S303': 'Success'}

# %% [markdown]
# Q88. Report exact paths in nested statements for banking case 2; use sample reference ACC-1088 and explain the result.

# %%
import re
reference = "ACC-1088"
data = {
    "customer": {
        "name": "Priya",
        "account": {
            "number": "987654321",
            "ifsc": "ICIC0004567"
        }
    }
}
checks = [
    ("customer.name", data["customer"]["name"], r"^[A-Za-z ]+$"),
    ("customer.account.number", data["customer"]["account"]["number"], r"^\d{10}$"),
    ("customer.account.ifsc", data["customer"]["account"]["ifsc"], r"^[A-Z]{4}0[A-Z0-9]{6}$")
]
invalid_paths = []
for path, value, pattern in checks:
    if not re.match(pattern, value):
        invalid_paths.append(path)
print(reference)
print("Invalid paths:", invalid_paths)
# Out:
# ACC-1088
# Invalid paths: ['customer.account.number']

# %% [markdown]
# Q89. Design idempotent recovery after timeout for banking case 2; use sample reference ACC-1089 and explain the result.

# %%
import re
reference = "ACC-1089"
amount = "4000"
processed = set()
if re.match(r"^\d+$", amount):
    if reference not in processed:
        processed.add(reference)
        print(f"{reference}: Payment processed")
    else:
        print(f"{reference}: Duplicate payment ignored")
if reference in processed:
    print(f"{reference}: Recovery skipped, payment already completed")
# Out:
# ACC-1089: Payment processed
# ACC-1089: Recovery skipped, payment already completed

# %% [markdown]
# Q90. Build an exception-safe reconciliation pipeline for banking case 2; use sample reference ACC-1090 and explain the result.

# %%
import re
reference = "ACC-1090"
bank = {
    "T301": "2000",
    "T302": "wrong",
    "T303": "4500"
}
system = {
    "T301": 2000,
    "T302": 2500,
    "T303": 4000
}
results = {}
for transaction_id in bank:
    amount = bank[transaction_id]
    if not re.match(r"^\d+$", amount):
        results[transaction_id] = "Failed"
        continue
    if int(amount) == system[transaction_id]:
        results[transaction_id] = "Matched"
    else:
        results[transaction_id] = "Mismatch"
print(reference)
print("Results:", results)
# Out:
# ACC-1090
# Results: {'T301': 'Matched', 'T302': 'Failed', 'T303': 'Mismatch'}

# %% [markdown]
# Q91. Design a banking exception hierarchy for banking case 3; use sample reference ACC-1091 and explain the result.

# %%
class BankingError(Exception):
    pass
class InvalidAccount(BankingError):
    pass
class InsufficientFunds(BankingError):
    pass
class TransferLimitExceeded(BankingError):
    pass
def transfer(account, amount):
    if account != "ACC-1091":
        raise InvalidAccount("Account does not exist")
    if amount > 50000:
        raise TransferLimitExceeded("Transfer limit exceeded")
    balance = 30000
    if amount > balance:
        raise InsufficientFunds("Insufficient balance")
    return balance - amount
try:
    remaining = transfer("ACC-1091", 45000)
    print("Transfer successful")
    print("Remaining balance:", remaining)
except TransferLimitExceeded as e:
    print("Limit Error:", e)
except InsufficientFunds as e:
    print("Balance Error:", e)
except BankingError as e:
    print("Banking Error:", e)
# Out:
# Balance Error: Insufficient balance

# %% [markdown]
# Q92. Make a transfer rollback-safe for banking case 3; use sample reference ACC-1092 and explain the result.

# %%
balance = 40000
reference = "ACC-1092"
def make_transfer(amount):
    global balance
    old_balance = balance
    try:
        balance -= amount
        if balance < 0:
            raise ValueError("Insufficient balance")
        print("Transfer completed:", amount)
    except Exception as error:
        balance = old_balance
        print("Transfer failed:", error)
        print("Transaction rolled back")
print("Reference:", reference)
print("Before:", balance)
make_transfer(50000)
print("After:", balance)
# Out:
# Reference: ACC-1092
# Before: 40000
# Transfer failed: Insufficient balance
# Transaction rolled back
# After: 40000

# %% [markdown]
# Q93. Preserve causes across service layers for banking case 3; use sample reference ACC-1093 and explain the result.

# %%
def database_service():
    raise ConnectionError("Bank database unavailable")
def account_service():
    try:
        database_service()
    except ConnectionError as error:
        raise RuntimeError("Account service could not fetch account") from error
def payment_service():
    try:
        account_service()
    except RuntimeError as error:
        raise Exception("Payment service failed") from error
try:
    payment_service()
except Exception as error:
    print("Final Error:", error)
    print("Original Cause:", error.__cause__)
# Out:
# Final Error: Payment service failed
# Original Cause: Account service could not fetch account

# %% [markdown]
# Q94.Implement bounded exponential retry for banking case 3; use sample reference ACC-1094 and explain the result.

# %%
import time
reference = "ACC-1094"
attempts = 0
max_attempts = 4
def connect_bank():
    global attempts
    attempts += 1
    if attempts < 3:
        raise ConnectionError("Bank server unavailable")
    return "Connection successful"
for attempt in range(max_attempts):
    try:
        result = connect_bank()
        print(reference, result)
        break
    except ConnectionError as error:
        if attempt == max_attempts - 1:
            print("All retries failed:", error)
        else:
            delay = 2 ** attempt
            print("Retry", attempt + 1, "after", delay, "seconds")
            time.sleep(delay)
# Out:
# Retry 1 after 1 seconds
# Retry 2 after 2 seconds
# ACC-1094 Connection successful

# %% [markdown]
# Q95. Create a transaction context manager for banking case 3; use sample reference ACC-1095 and explain the result.

# %%
class BankTransaction:
    def __init__(self, reference):
        self.reference = reference
    def __enter__(self):
        print("Transaction started:", self.reference)
        return self
    def __exit__(self, exc_type, exc_value, traceback):
        if exc_type:
            print("Transaction cancelled")
            print("Reason:", exc_value)
        else:
            print("Transaction committed")
try:
    with BankTransaction("ACC-1095"):
        print("Updating account")
        raise ValueError("Invalid transaction amount")
except ValueError:
    print("Handled transaction error")
# Out:
# Transaction started: ACC-1095
# Updating account
# Transaction cancelled
# Reason: Invalid transaction amount
# Handled transaction error

# %% [markdown]
# Q96. Build a dead-letter queue for payment events for banking case 3; use sample reference ACC-1096 and explain the result.

# %%
payments = [
    ("PAY101", 500),
    ("PAY102", -200),
    ("PAY103", 1000)
]
dead_letter_queue = []
for payment_id, amount in payments:
    try:
        if amount <= 0:
            raise ValueError("Invalid payment amount")
        print(payment_id, "processed successfully")
    except Exception as error:
        dead_letter_queue.append({
            "id": payment_id,
            "amount": amount,
            "error": str(error)
        })
print("\nDead Letter Queue:")
for item in dead_letter_queue:
    print(item)
# Out:
# PAY101 processed successfully
# PAY103 processed successfully
#
# Dead Letter Queue:
# {'id': 'PAY102', 'amount': -200, 'error': 'Invalid payment amount'}

# %% [markdown]
# Q97. Make batch settlement failure-isolated for banking case 3; use sample reference ACC-1097 and explain the result.

# %%
settlements = [
    ("ACC-1097-A", 1000),
    ("ACC-1097-B", -500),
    ("ACC-1097-C", 2000),
    ("ACC-1097-D", 1500)
]
successful = []
failed = []
for account, amount in settlements:
    try:
        if amount <= 0:
            raise ValueError("Settlement amount must be positive")
        successful.append(account)
        print(account, "settled")
    except ValueError as error:
        failed.append((account, str(error)))
        print(account, "failed")
print("\nSuccessful:", successful)
print("Failed:", failed)
# Out:
# ACC-1097-A settled
# ACC-1097-B failed
# ACC-1097-C settled
# ACC-1097-D settled
#
# Successful: ['ACC-1097-A', 'ACC-1097-C', 'ACC-1097-D']
# Failed: [('ACC-1097-B', 'Settlement amount must be positive')]

# %% [markdown]
# Q98. Report exact paths in nested statements for banking case 3; use sample reference ACC-1098 and explain the result.

# %%
def check_statement(data, path="root"):
    if isinstance(data, dict):
        for key, value in data.items():
            check_statement(value, path + "." + key)
    elif isinstance(data, list):
        for index, value in enumerate(data):
            check_statement(value, path + "[" + str(index) + "]")
    elif not isinstance(data, (int, float)):
        print("Invalid value at:", path)
statement = {
    "account": "ACC-1098",
    "customer": {
        "name": "Ravi",
        "transactions": [
            {"amount": 500},
            {"amount": "invalid"}
        ]
    }
}
check_statement(statement)
# Out:
# Invalid value at: root.account
# Invalid value at: root.customer.name
# Invalid value at: root.customer.transactions[1].amount

# %% [markdown]
# Q99. Design idempotent recovery after timeout for banking case 3; use sample reference ACC-1099 and explain the result.

# %%
processed = set()
def process_payment(reference, amount):
    if reference in processed:
        print(reference, "already processed - skipping duplicate")
        return
    print("Processing payment:", reference)
    processed.add(reference)
    print("Payment completed:", amount)
reference = "ACC-1099"
try:
    process_payment(reference, 2500)
    raise TimeoutError("Response timed out")
except TimeoutError:
    print("Timeout occurred. Retrying...")
    process_payment(reference, 2500)
# Out:
# Processing payment: ACC-1099
# Payment completed: 2500
# Timeout occurred. Retrying...
# ACC-1099 already processed - skipping duplicate

# %% [markdown]
# Q100. Build an exception-safe reconciliation pipeline for banking case 3; use sample reference ACC-1100 and explain the result.

# %%
records = [
    ("ACC-1100-A", 1000, 1000),
    ("ACC-1100-B", 2000, 1800),
    ("ACC-1100-C", 1500, 1500)
]
matched = []
unmatched = []
for account, ledger, bank in records:
    try:
        if ledger != bank:
            raise ValueError("Amount mismatch")
        matched.append(account)
    except ValueError as error:
        unmatched.append({
            "account": account,
            "reason": str(error)
        })
print("Matched Accounts:", matched)
print("Exceptions:", unmatched)
print("Reconciliation completed")
# Out:
# Matched Accounts: ['ACC-1100-A', 'ACC-1100-C']
# Exceptions: [{'account': 'ACC-1100-B', 'reason': 'Amount mismatch'}]
# Reconciliation completed
