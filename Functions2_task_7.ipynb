# %% [markdown]
# Python Assignment: Lambda, map(), filter(), reduce(), and Combined Operations

# %% [markdown]
# Section 1: Lambda Expressions

# %% [markdown]
# Question 1

# %%
## Write a lambda expression to calculate the square of number.
## number= 8
square = 8
square=lambda x:x**2
square(8)
# Out:
# 64

# %% [markdown]
# Question 2

# %%
## Write a lambda expression to calculate the cube of number.
## number = 5
cube = 5
cube=lambda x:x**3
cube(5)
# Out:
# 125

# %% [markdown]
# Question 3

# %%
## Write a lambda expression to add a and b.
## a,b = 25, 17
add=lambda a,b:a+b
add(25,17)
# Out:
# 42

# %% [markdown]
# Question 4

# %%
## Write a lambda expression to subtract b from a.
## a = 50 ,b = 18
sub=lambda a,b:a-b
sub(50,18)
# Out:
# 32

# %% [markdown]
# Question 5

# %%
## Write a lambda expression to multiply a and b.
## a = 12, b = 9
multiply=lambda a,b:a*b
multiply(12,9)
# Out:
# 108

# %% [markdown]
# Question 6

# %%
## Write a lambda expression to divide a by b.
## a = 100 , b = 4
div = lambda a,b:a/b
div(100,4)
# Out:
# 25.0

# %% [markdown]
# Question 7

# %%
## Write a lambda expression to return the larger number.
## a = 72 , b = 91
larger = lambda a,b : b if a < b else b
larger(72,91)
# Out:
# 91

# %% [markdown]
# Question 8

# %%
## Write a lambda expression to return the smaller number.
## a = 46, b = 28
smaller = lambda a,b : a if a > b else a
smaller(46,28)
# Out:
# 46

# %% [markdown]
# Question 9

# %%
## Write a lambda expression that returns True when the number is even and False otherwise.
## number = 34
number = 34
is_even = lambda x : x % 2 == 0
print(is_even(number))
# Out:
# True

# %% [markdown]
# Question 10

# %%
## Write a lambda expression that returns True when the number is odd and False otherwise.
number = 27
is_odd = lambda x : x % 2 != 0
print(is_odd(number))
# Out:
# True

# %% [markdown]
# Question 11

# %%
## length = 12
## width = 8
## Write a lambda expression to calculate the area of a rectangle.
length = 12
width = 8
area = lambda l, w:(l*w)
print("Rectangle:",area(length,width))
# Out:
# Rectangle: 96

# %% [markdown]
# Question 12

# %%
## Write a lambda expression to calculate the area of a circle using 3.14.
radius = 7
area = lambda r: 3.14 * r **2
print(area(7))
# Out:
# 153.86

# %% [markdown]
# Question 13

# %%
## Write a lambda expression to calculate the perimeter of a rectangle.
length = 15
width = 10
perimeter = lambda l, w: 2 * (l + w)

print("Perimeter of Rectangle =", perimeter(length, width))
# Out:
# Perimeter of Rectangle = 50

# %% [markdown]
# Question 14

# %%
## Write a lambda expression to convert Celsius into Fahrenheit.
celsius = 35
Fahrenheit = lambda c: (c * 9/5) + 32
print("Fahrenheit:",Fahrenheit(celsius))
# Out:
# Fahrenheit: 95.0

# %% [markdown]
# Question 15

# %%
## Write a lambda expression to convert Fahrenheit into Celsius.
fahrenheit = 104
celsius = lambda f: (f - 32) * 5 / 9

print("Temperature in Celsius =", celsius(fahrenheit))
# Out:
# Temperature in Celsius = 40.0

# %% [markdown]
# Question 16

# %%
## Write a lambda expression to return the length of the string.
word = "Python"
string_length = lambda x: len(word)
string_length(word)
# Out:
# 6

# %% [markdown]
# Question 17

# %%
## Write a lambda expression to return the first character of the string.
word = "Azure"
first_char = lambda word: word[0]
print("First Character =", first_char(word))
# Out:
# First Character = A

# %% [markdown]
# Question 18

# %%
## Write a lambda expression to return the last character of the string.
word = "Databricks"
last_char = lambda word : word[-1]
print("Last character:", last_char(word))
# Out:
# Last character: s

# %% [markdown]
# Question 19

# %%
## Write a lambda expression to return the absolute value of the number without using abs().
number = -45
absolute = lambda n: n if n >= 0 else -n
print("Absolute=",absolute(number))
# Out:
# Absolute= 45

# %% [markdown]
# Question 20

# %%
## Write a lambda expression that returns:

##"Distinction" when marks are 75 or above
##"Pass" when marks are 40 to 74
##"Fail" when marks are below 40
marks = 72
result = lambda m: "Distinction" if m >= 75 else "Pass" if m >= 40 else "Fail"
print("Marks:",result(marks))
# Out:
# Marks: Pass

# %% [markdown]
# Section 2: map()

# %% [markdown]
# Question 1

# %%
## Using map() and a lambda expression, calculate the square of every number.
numbers = [1, 2, 3, 4, 5, 6]
squares = list(map(lambda x: x ** 2, numbers))
print("Squares:",squares)
# Out:
# Squares: [1, 4, 9, 16, 25, 36]

# %% [markdown]
# Question 2

# %%
## Using map() and a lambda expression, calculate the cube of every number.
numbers = [2, 3, 4, 5, 6]
cubes = list(map(lambda x: x ** 2, numbers))
print("Cubes:",cubes)
# Out:
# Cubes: [4, 9, 16, 25, 36]

# %% [markdown]
# Question 3

# %%
## Using map(), add 5 to every number.
numbers = [10, 20, 30, 40, 50]
result = list(map(lambda x: x + 5, numbers))
print("Updated list:",result)
# Out:
# Updated list: [15, 25, 35, 45, 55]

# %% [markdown]
# Question 4

# %%
## Using map(), subtract 10 from every number.
numbers = [15, 25, 35, 45, 55]
result = list(map(lambda x: x - 10 , numbers))
print("Updated list:",result)
# Out:
# Updated list: [5, 15, 25, 35, 45]

# %% [markdown]
# Question 5

# %%
## Using map(), multiply every number by 100.
numbers = [1, 5, 10, 15, 20]
result = list(map(lambda x: x *  1000 , numbers))
print("Updated list:",result)
# Out:
# Updated list: [1000, 5000, 10000, 15000, 20000]

# %% [markdown]
# Question 6

# %%
## Using map(), convert every name to uppercase.
names = ["ravi", "anil", "meena", "kiran", "sneha"]
result = list(map(lambda names: names.upper() , names))
print("Updated list:",result)
# Out:
# Updated list: ['RAVI', 'ANIL', 'MEENA', 'KIRAN', 'SNEHA']

# %% [markdown]
# Question 7

# %%
## Using map(), convert every name to lowercase.
names = ["RAHUL", "DIVYA", "ARJUN", "AJAY"]
result = list(map(lambda names: names.lower() , names))
print("Updated list:",result)
# Out:
# Updated list: ['rahul', 'divya', 'arjun', 'ajay']

# %% [markdown]
# Question 8

# %%
## Using map(), convert every name to title case.
names = ["rahul kumar", "anil sharma", "meena reddy", "divya singh"]
result = list(map(lambda names: names.title() , names))
print("Updated list:",result)
# Out:
# Updated list: ['Rahul Kumar', 'Anil Sharma', 'Meena Reddy', 'Divya Singh']

# %% [markdown]
# Question 9

# %%
## Using map(), extract the first character of every word.
words = ["Python", "Azure", "Docker", "Linux", "Spark"]
result = list(map(lambda word: word[0] , words))
print("Updated list:",result)
# Out:
# Updated list: ['P', 'A', 'D', 'L', 'S']

# %% [markdown]
# Question 10

# %%
## Using map(), extract the last character of every word.
words = ["Python", "Azure", "Docker", "Linux", "Spark"]
result = list(map(lambda word: word[-1] , words))
print("Updated list:",result)
# Out:
# Updated list: ['n', 'e', 'r', 'x', 'k']

# %% [markdown]
# Question 11

# %%
## Using map(), convert every Celsius temperature into Fahrenheit.
temperatures = [0, 10, 20, 30, 40]
fahrenheit = list(map(lambda c: (c * 9/5) + 32, temperatures))
print("Temperatures in Fahrenheit =", fahrenheit)
# Out:
# Temperatures in Fahrenheit = [32.0, 50.0, 68.0, 86.0, 104.0]

# %% [markdown]
# Question 12

# %%
## Using map(), calculate the length of every word.
words = ["Python", "Azure", "Databricks", "Cloud", "AI"]
result = list(map(lambda x: len(x), words))
print(result)
# Out:
# [6, 5, 10, 5, 2]

# %% [markdown]
# Question 13

# %%
## Using map(), calculate 18% GST for every price.
prices = [100, 250, 500, 1000, 2500]
gst = list(map(lambda price: price * 18 / 100, prices))
print("18% GST for each price =", gst)
# Out:
# 18% GST for each price = [18.0, 45.0, 90.0, 180.0, 450.0]

# %% [markdown]
# Question 14

# %%
## Using map(), calculate the final price after adding 18% GST.
prices = [100, 250, 500, 1000, 2500]
final_prices = list(map(lambda price: price + (price * 18 / 100), prices))
print("Final Prices after 18% GST =", final_prices)
# Out:
# Final Prices after 18% GST = [118.0, 295.0, 590.0, 1180.0, 2950.0]

# %% [markdown]
# Question 15

# %%
## Using map(), round every number to two decimal places.
decimal_numbers = [12.4567, 45.8976, 78.1234, 99.9999]
rounded_numbers = list(map(lambda x: round(x, 2), decimal_numbers))
print("Rounded Numbers =", rounded_numbers)
# Out:
# Rounded Numbers = [12.46, 45.9, 78.12, 100.0]

# %% [markdown]
# Question 16

# %%
## Using map(), convert every number into its absolute value.
values = [-10, 20, -35, 40, -55, 60]
absolute = list(map(lambda x: x if x >= 0 else -x, values))
print("Absloute:",absolute)
# Out:
# Absloute: [10, 20, 35, 40, 55, 60]

# %% [markdown]
# Question 17

# %%
## Using map(), convert every integer into a string.
numbers = [10, 20, 30, 40, 50]
string_numbers = list(map(lambda x: str(x), numbers))
print("String:",string_numbers)
# Out:
# String: ['10', '20', '30', '40', '50']

# %% [markdown]
# Question 18

# %%
## Using map(), remove leading and trailing spaces from every name.
names = ["  Ravi  ", " Anil", "Meena ", "  Kiran "]
clean_names = list(map(lambda name: name.strip(), names))
print("Names:",clean_names)
# Out:
# Names: ['Ravi', 'Anil', 'Meena', 'Kiran']

# %% [markdown]
# Question 19

# %%
## Using map(), extract only employee names.
employees = [
    {"id": 101, "name": "Rahul", "salary": 45000},
    {"id": 102, "name": "Anil", "salary": 65000},
    {"id": 103, "name": "Sneha", "salary": 72000},
    {"id": 104, "name": "Kiran", "salary": 82000}
]
employee_names = list(map(lambda emp: emp["name"], employees))
print("Employee Names =", employee_names)
# Out:
# Employee Names = ['Rahul', 'Anil', 'Sneha', 'Kiran']

# %% [markdown]
# Question 20

# %%
## Using map(), create a new list of dictionaries containing:
##Employee name
##Original salary
##Salary after a 10% increment

employees = [
    {"id": 101, "name": "Rahul", "salary": 45000},
    {"id": 102, "name": "Anil", "salary": 65000},
    {"id": 103, "name": "Sneha", "salary": 72000},
    {"id": 104, "name": "Kiran", "salary": 82000}
]
updated_employees = list(map(lambda emp: {
    "name": emp["name"],
    "original_salary": emp["salary"],
    "salary_after_increment": emp["salary"] + (emp["salary"] * 10 / 100)
}, employees))

print(updated_employees)
# Out:
# [{'name': 'Rahul', 'original_salary': 45000, 'salary_after_increment': 49500.0}, {'name': 'Anil', 'original_salary': 65000, 'salary_after_increment': 71500.0}, {'name': 'Sneha', 'original_salary': 72000, 'salary_after_increment': 79200.0}, {'name': 'Kiran', 'original_salary': 82000, 'salary_after_increment': 90200.0}]

# %% [markdown]
# Section 3: filter()

# %% [markdown]
# Question 1

# %%
## Using filter(), extract all even numbers.
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
even_numbers = list(filter(lambda x: x % 2 == 0, numbers))
print("Even Numbers =", even_numbers)
# Out:
# Even Numbers = [12, 56, 34, 78, 100]

# %% [markdown]
# Question 2

# %%
## Using filter(), extract all odd numbers.
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
odd_numbers = list(filter(lambda x: x % 2 != 0, numbers))
print("Odd Numbers =", odd_numbers)
# Out:
# Odd Numbers = [45, 67, 89, 23, 91]

# %% [markdown]
# Question 3

# %%
## Using filter(), extract all numbers greater than 50.
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
result = list(filter(lambda x: x > 50,numbers))
print("Numbers:",result)
# Out:
# Numbers: [67, 89, 56, 91, 78, 100]

# %% [markdown]
# Question 4

# %%
## Using filter(), extract all numbers less than 100.
numbers = [120, 45, 167, 89, 230, 56, 91, 34, 178, 100]
result = list(filter(lambda x: x < 100,numbers))
print("Numbers:",result)
# Out:
# Numbers: [45, 89, 56, 91, 34]

# %% [markdown]
# Question 5

# %%
## Using filter(), extract all positive numbers.
numbers = [-15, -8, 0, 4, 12, -25, 37, 42]
result = list(filter(lambda x: x > 0, numbers))
print("Positive numbers:",result)
# Out:
# Positive numbers: [4, 12, 37, 42]

# %% [markdown]
# Question 6

# %%
## Using filter(), extract all negative numbers.
numbers = [-15, -8, 0, 4, 12, -25, 37, 42]
result = list(filter(lambda x: x < 0, numbers))
print("Negative numbers:",result)
# Out:
# Negative numbers: [-15, -8, -25]

# %% [markdown]
# Question 7

# %%
## Using filter(), remove all zero values.
numbers = [-15, -8, 0, 4, 12, 0, -25, 37, 0]
list(filter(lambda x: x != 0 , numbers))
# Out:
# [-15, -8, 4, 12, -25, 37]

# %% [markdown]
# Question 8

# %%
## Using filter(), extract words containing more than five characters.
words = ["python", "azure", "ai", "developer", "cloud", "analytics"]
list(filter(lambda x: True if len(x)>5 else False,words))
# Out:
# ['python', 'developer', 'analytics']

# %% [markdown]
# Question 9

# %%
## Using filter(), extract names beginning with "A".
names = ["Anil", "Rahul", "Ajay", "Meena", "Arjun", "Kiran", "Akhil"]
list(filter(lambda name: name.startswith("A"), names))
# Out:
# ['Anil', 'Ajay', 'Arjun', 'Akhil']

# %% [markdown]
# Question 10

# %%
## Using filter(), extract names ending with "n".
names = ["Kiran", "Mohan", "Arjun", "Rajan", "Meena", "Varun"]
list(filter(lambda name: name.endswith("n"), names))
# Out:
# ['Kiran', 'Mohan', 'Arjun', 'Rajan', 'Varun']

# %% [markdown]
# Question 11

# %%
## Using filter(), extract all multiples of 5.
numbers = [10, 15, 18, 20, 25, 30, 32, 40, 45, 50]
list(filter(lambda x: x % 5 == 0, numbers))
# Out:
# [10, 15, 20, 25, 30, 40, 45, 50]

# %% [markdown]
# Question 12

# %%
## Using filter(), extract numbers divisible by both 3 and 5.
numbers = [3, 5, 10, 15, 18, 30, 42, 45, 60, 75]
list(filter(lambda x: x % 3 == 0 and x % 5 == 0 , numbers))
# Out:
# [15, 30, 45, 60, 75]

# %% [markdown]
# Question 13

# %%
## Using filter(), extract all palindrome words.
words = ["madam", "python", "level", "azure", "radar", "cloud", "civic"]
list(filter(lambda word: word == word[::-1], words))
# Out:
# ['madam', 'level', 'radar', 'civic']

# %% [markdown]
# Question 14

# %%
## Using filter(), extract email addresses ending with ".com".
emails = [
    "john@gmail.com",
    "rahul@yahoo.com",
    "admin@python.com",
    "support@azure.org",
    "sales@company.com"
]
list(filter(lambda email: email.endswith(".com"), emails))
# Out:
# ['john@gmail.com', 'rahul@yahoo.com', 'admin@python.com', 'sales@company.com']

# %% [markdown]
# Question 15

# %%
## Using filter(), extract all CSV files.
files = [
    "sales.csv",
    "employees.xlsx",
    "products.csv",
    "report.pdf",
    "customers.csv",
    "notes.txt"
]

list(filter(lambda file: file.endswith(".csv"), files))
# Out:
# ['sales.csv', 'products.csv', 'customers.csv']

# %% [markdown]
# Question 16

# %%
## Using filter(), extract employees whose salary is greater than 60000.
employees = [
    {"name": "Rahul", "salary": 45000},
    {"name": "Anil", "salary": 65000},
    {"name": "Sneha", "salary": 72000},
    {"name": "Kiran", "salary": 82000},
    {"name": "Meena", "salary": 55000}
]

list(filter(lambda emp: emp["salary"] > 60000, employees))
# Out:
# [{'name': 'Anil', 'salary': 65000},
#  {'name': 'Sneha', 'salary': 72000},
#  {'name': 'Kiran', 'salary': 82000}]

# %% [markdown]
# Question 17

# %%
## Using filter(), extract students who scored more than 80.
students = [
    {"name": "Ravi", "marks": 92},
    {"name": "Kiran", "marks": 68},
    {"name": "Meena", "marks": 85},
    {"name": "Ajay", "marks": 48},
    {"name": "Sneha", "marks": 79}
]
list(filter(lambda student: student["marks"] > 80, students))
# Out:
# [{'name': 'Ravi', 'marks': 92}, {'name': 'Meena', 'marks': 85}]

# %% [markdown]
# Question 18

# %%
## Using filter(), extract products that are currently in stock.
products = [
    {"name": "Laptop", "price": 55000, "stock": 5},
    {"name": "Mouse", "price": 600, "stock": 25},
    {"name": "Keyboard", "price": 1500, "stock": 0},
    {"name": "Monitor", "price": 18000, "stock": 8},
    {"name": "Printer", "price": 12000, "stock": 0}
]
list(filter(lambda product: product["stock"] != 0, products))
# Out:
# [{'name': 'Laptop', 'price': 55000, 'stock': 5},
#  {'name': 'Mouse', 'price': 600, 'stock': 25},
#  {'name': 'Monitor', 'price': 18000, 'stock': 8}]

# %% [markdown]
# Question 19

# %%
## Using filter(), extract people who are eligible to vote.
people = [
    {"name": "Rahul", "age": 17},
    {"name": "Anil", "age": 25},
    {"name": "Sneha", "age": 16},
    {"name": "Kiran", "age": 32},
    {"name": "Meena", "age": 18}
]
list(filter(lambda people: people["age"] > 18, people))
# Out:
# [{'name': 'Anil', 'age': 25}, {'name': 'Kiran', 'age': 32}]

# %% [markdown]
# Question 20

# %%
## Using filter(), extract employees who belong to the IT department and are active.
employees = [
    {"name": "Rahul", "department": "IT", "active": True},
    {"name": "Anil", "department": "HR", "active": True},
    {"name": "Sneha", "department": "IT", "active": False},
    {"name": "Kiran", "department": "IT", "active": True},
    {"name": "Meena", "department": "Sales", "active": True}
]
list(filter(lambda emp: emp["department"] == "IT" and emp["active"],employees))
# Out:
# [{'name': 'Rahul', 'department': 'IT', 'active': True},
#  {'name': 'Kiran', 'department': 'IT', 'active': True}]

# %% [markdown]
# Section 4: reduce()

# %% [markdown]
# Question 1

# %%
## Using reduce(), calculate the sum of all numbers.
from functools import reduce
numbers = [10, 20, 30, 40, 50]
reduce(lambda x,y:x+y,numbers)
# Out:
# 150

# %% [markdown]
# Question 2

# %%
## Using reduce(), calculate the product of all numbers.
numbers = [2, 3, 4, 5]
reduce(lambda x,y:x*y,numbers)
# Out:
# 120

# %% [markdown]
# Question 3

# %%
## Using reduce(), find the maximum number.
numbers = [45, 12, 89, 34, 67, 91, 28]
reduce(lambda x,y:max(x,y),numbers)
# Out:
# 91

# %% [markdown]
# Question 4

# %%
## Using reduce(), find the minimum number.
numbers = [45, 12, 89, 34, 67, 91, 28]
reduce(lambda x,y:min(x,y),numbers)
# Out:
# 12

# %% [markdown]
# Question 5

# %%
## Using reduce(), combine all strings into one sentence.
words = ["Python", " ", "is", " ", "powerful"]
reduce(lambda x,y:x+y,words)
# Out:
# 'Python is powerful'

# %% [markdown]
# Question 6

# %%
## Using reduce(), calculate the total number of characters in all words.
words = ["Python", "Azure", "Cloud", "AI"]
reduce(lambda total,word:total+len(word),words,0)
# Out:
# 18

# %% [markdown]
# Question 7

# %%
## Using reduce(), calculate the factorial of number.
number = 6
numbers = list(range(1, number + 1))
reduce(lambda x, y: x * y, numbers)
# Out:
# 720

# %% [markdown]
# Question 8

# %%
## Using reduce(), calculate the sum of only the even numbers. Do not create a separate filtered list.
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
reduce(lambda total, x: total + x if x % 2 == 0 else total, numbers, 0)
# Out:
# 280

# %% [markdown]
# Question 9

# %%
## Using reduce(), calculate the sum of only the odd numbers. Do not create a separate filtered list.
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
reduce(lambda total, x: total + x if x % 2 != 0 else total, numbers, 0)
# Out:
# 315

# %% [markdown]
# Question 10

# %%
## Using reduce(), find the longest word.
words = ["AI", "Python", "Databricks", "Cloud", "Kubernetes"]
reduce(lambda x, y: x if len(x) > len(y) else y, words)
# Out:
# 'Kubernetes'

# %% [markdown]
# Question 11

# %%
## Using reduce(), find the shortest word.
words = ["AI", "Python", "Databricks", "Cloud", "Kubernetes"]
reduce(lambda x, y: x if len(x) < len(y) else y, words)
# Out:
# 'AI'

# %% [markdown]
# Question 12

# %%
## Using reduce(), calculate the total salary.
salaries = [45000, 65000, 72000, 82000, 55000]
reduce(lambda x, y: x + y, salaries)
# Out:
# 319000

# %% [markdown]
# Question 13

# %%
## Using reduce(), calculate the total payroll directly from the dictionaries.
employees = [
    {"name": "Rahul", "salary": 45000},
    {"name": "Anil", "salary": 65000},
    {"name": "Sneha", "salary": 72000},
    {"name": "Kiran", "salary": 82000},
    {"name": "Meena", "salary": 55000}
]
reduce(lambda total, emp: total + emp["salary"], employees, 0)
# Out:
# 319000

# %% [markdown]
# Question 14

# %%
## Using reduce(), find the employee with the highest salary.
employees = [
    {"name": "Rahul", "salary": 45000},
    {"name": "Anil", "salary": 65000},
    {"name": "Sneha", "salary": 72000},
    {"name": "Kiran", "salary": 82000},
    {"name": "Meena", "salary": 55000}
]
reduce(lambda x, y: x if x["salary"] > y["salary"] else y,employees)
# Out:
# {'name': 'Kiran', 'salary': 82000}

# %% [markdown]
# Question 15

# %%
## Using reduce(), find the student with the highest marks.
students = [
    {"name": "Ravi", "marks": 92},
    {"name": "Kiran", "marks": 68},
    {"name": "Meena", "marks": 85},
    {"name": "Ajay", "marks": 48},
    {"name": "Rahul", "marks": 95}
]
reduce(lambda x, y: x if x["marks"] > y["marks"] else y,students)
# Out:
# {'name': 'Rahul', 'marks': 95}

# %% [markdown]
# Question 16

# %%
## Using reduce(), calculate the total stock quantity.
products = [
    {"name": "Laptop", "price": 55000, "stock": 5},
    {"name": "Mouse", "price": 600, "stock": 25},
    {"name": "Keyboard", "price": 1500, "stock": 15},
    {"name": "Monitor", "price": 18000, "stock": 8}
]
reduce(lambda total, product: total + product["stock"], products, 0)
# Out:
# 53

# %% [markdown]
# Question 17

# %%
## Using reduce(), calculate the total inventory value using price × stock.
products = [
    {"name": "Laptop", "price": 55000, "stock": 5},
    {"name": "Mouse", "price": 600, "stock": 25},
    {"name": "Keyboard", "price": 1500, "stock": 15},
    {"name": "Monitor", "price": 18000, "stock": 8}
]
reduce(lambda total, product: total + (product["price"] * product["stock"]),products,0)
# Out:
# 456500

# %% [markdown]
# Question 18

# %%
## Using reduce(), calculate the total sales amount.
sales = [12000, 25000, 18000, 45000, 30000, 52000]
reduce(lambda x, y: x + y, sales)
# Out:
# 182000

# %% [markdown]
# Question 19

# %%
## Using reduce(), merge all dictionaries into one dictionary.
dictionaries = [
    {"name": "Rahul"},
    {"age": 30},
    {"department": "IT"},
    {"salary": 65000}
]
reduce(lambda x, y: {**x, **y}, dictionaries)
# Out:
# {'name': 'Rahul', 'age': 30, 'department': 'IT', 'salary': 65000}

# %% [markdown]
# Question 20

# %%
## Using reduce(), calculate the sum of unique numbers only. Do not directly use sum(set(numbers)).
numbers = [12, 45, 12, 67, 45, 89, 23, 67, 100]
reduce(lambda total, x: total if x in numbers[:numbers.index(x)] else total + x,numbers,0)
# Out:
# 460

# %% [markdown]
# Section 5: Combined Lambda, map(), filter(), and reduce()

# %% [markdown]
# Question 1

# %%
## Using filter() and map():

#3Extract all even numbers.
##Calculate the square of every even number.
##Return the squared values as a list.
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
list(map(lambda x: x ** 2,filter(lambda x: x % 2 == 0, numbers)))
# Out:
# [144, 3136, 1156, 6084, 10000]

# %% [markdown]
# Question 2

# %%
## Using filter() and reduce():

##Extract all odd numbers.
##Calculate their total sum.
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
reduce(lambda x, y: x + y,filter(lambda x: x % 2 != 0, numbers))
# Out:
# 315

# %% [markdown]
# Question 3

# %%
## Using filter() and map():

## Extract numbers greater than 50.
## Multiply every selected number by 2.
numbers = [10, 25, 40, 55, 70, 85, 100]
list(map(lambda x: x * 2,filter(lambda x: x > 50, numbers)))
# Out:
# [110, 140, 170, 200]

# %% [markdown]
# Question 4

# %%
## Using filter(), map(), and reduce():
##Extract positive numbers.
## Calculate the square of every positive number.
##Calculate the total sum of the squared values.
numbers = [-15, 20, -35, 40, 50, -10, 60]
reduce(lambda x, y: x + y,map(lambda x: x ** 2,filter(lambda x: x > 0, numbers)))
# Out:
# 8100

# %% [markdown]
# Question 5

# %%
## Using filter() and map():
## Extract words containing more than five characters.
## Convert the selected words to uppercase.
words = ["python", "azure", "ai", "developer", "cloud", "analytics", "spark"]
list(map(lambda word: word.upper(),filter(lambda word: len(word) > 5, words)))
# Out:
# ['PYTHON', 'DEVELOPER', 'ANALYTICS']

# %% [markdown]
# Question 6

# %%
## Using filter() and map():
## Extract names beginning with "A".
## Convert the selected names to lowercase.
names = ["Anil", "Rahul", "Ajay", "Meena", "Arjun", "Kiran", "Akhil"]
list(map(lambda name: name.lower(),filter(lambda name: name.startswith("A"), names)))
# Out:
# ['anil', 'ajay', 'arjun', 'akhil']

# %% [markdown]
# Question 7

# %%
## Using filter() and reduce():
## Extract numbers divisible by both 3 and 5.
## Calculate their total sum
numbers = [3, 5, 10, 15, 18, 30, 42, 45, 60, 75]
reduce(lambda x, y: x + y,filter(lambda x: x % 3 == 0 and x % 5 == 0, numbers))
# Out:
# 225

# %% [markdown]
# Question 8

# %%
## Using filter() and reduce():

## Extract palindrome words.
## Join them into one string separated by " | ".
words = ["madam", "python", "level", "azure", "radar", "cloud", "civic"]
reduce(lambda x, y: x + " | " + y,filter(lambda word: word == word[::-1], words))
# Out:
# 'madam | level | radar | civic'

# %% [markdown]
# Question 9

# %%
## Using filter(), map(), and reduce():
## Extract temperatures greater than 30°C.
## Convert the selected values into Fahrenheit.
## Calculate the average Fahrenheit temperature.
temperatures = [18, 24, 30, 35, 40, 12, 28, 33, 15, 42]
temp = list(map(lambda c: (c * 9/5) + 32,filter(lambda c: c > 30, temperatures)))
total = reduce(lambda a, b: a + b, temp)
average = total / len(temp)
print(temp)
print(average)
# Out:
# [95.0, 104.0, 91.4, 107.6]
# 99.5

# %% [markdown]
# Question 10

# %%
## Using filter(), map(), and reduce():
## Extract prices greater than 1000.
## Apply a 10% discount to every selected price.
## Calculate the total discounted amount.
prices = [450, 1200, 2500, 800, 5000, 1500, 7500]
discount = list(map(lambda x: x * 0.9,filter(lambda x: x > 1000, prices)))
total = reduce(lambda a, b: a + b, discount)
print(discount)
print(total)
# Out:
# [1080.0, 2250.0, 4500.0, 1350.0, 6750.0]
# 15930.0

# %% [markdown]
# Question 11

# %%
## Using filter() and map():
## Extract employees earning more than 60000.
## Increase their salary by 10%.
## Return their names and updated salaries.
employees = [
    {"id": 101, "name": "Rahul", "salary": 45000},
    {"id": 102, "name": "Anil", "salary": 65000},
    {"id": 103, "name": "Sneha", "salary": 72000},
    {"id": 104, "name": "Kiran", "salary": 82000},
    {"id": 105, "name": "Meena", "salary": 55000}
]
list(map(lambda e: {"name": e["name"], "salary": e["salary"] * 1.10}, filter(lambda e: e["salary"] > 60000, employees)))
# Out:
# [{'name': 'Anil', 'salary': 71500.0},
#  {'name': 'Sneha', 'salary': 79200.0},
#  {'name': 'Kiran', 'salary': 90200.00000000001}]

# %% [markdown]
# Question 12

# %%
## Using filter() and reduce():
## Extract employees from the IT department.
## Calculate the total salary of IT employees.
employees = [
    {"id": 101, "name": "Rahul", "department": "IT", "salary": 45000},
    {"id": 102, "name": "Anil", "department": "HR", "salary": 65000},
    {"id": 103, "name": "Sneha", "department": "IT", "salary": 72000},
    {"id": 104, "name": "Kiran", "department": "IT", "salary": 82000},
    {"id": 105, "name": "Meena", "department": "Sales", "salary": 55000}
]
it = filter(lambda e: e["department"] == "IT", employees)
total = reduce(lambda a, b: a + b["salary"], it, 0)

print(total)
# Out:
# 199000

# %% [markdown]
# Question 13

# %%
## Using filter(), map(), and reduce():
## Extract active employees.
## Increase every active employee's salary by 15%.
## Calculate the total updated payroll.
employees = [
    {"id": 101, "name": "Rahul", "salary": 45000, "active": True},
    {"id": 102, "name": "Anil", "salary": 65000, "active": True},
    {"id": 103, "name": "Sneha", "salary": 72000, "active": False},
    {"id": 104, "name": "Kiran", "salary": 82000, "active": True},
    {"id": 105, "name": "Meena", "salary": 55000, "active": True},
    {"id": 106, "name": "Arjun", "salary": 98000, "active": False}
]
updated = list(map(lambda e: e["salary"] * 1.15, filter(lambda e: e["active"], employees)))
payroll = reduce(lambda a, b: a + b, updated)
print(updated)
print(payroll)
# Out:
# [51749.99999999999, 74750.0, 94299.99999999999, 63249.99999999999]
# 284050.0

# %% [markdown]
# Question 14

# %%
## Using filter() and reduce():
## Extract students who passed.
## Find the topper among the passed students.
students = [
    {"name": "Ravi", "marks": 92, "passed": True},
    {"name": "Kiran", "marks": 68, "passed": True},
    {"name": "Meena", "marks": 85, "passed": True},
    {"name": "Ajay", "marks": 48, "passed": True},
    {"name": "Sneha", "marks": 35, "passed": False},
    {"name": "Rahul", "marks": 95, "passed": True}
]
reduce(lambda x, y: x if x["marks"] > y["marks"] else y,filter(lambda student: student["passed"], students))
# Out:
# {'name': 'Rahul', 'marks': 95, 'passed': True}

# %% [markdown]
# Question 15

# %%
## Using filter(), map(), and reduce():
## Extract students scoring more than 70.
## Extract only their marks.
## Calculate the average marks.
students = [
    {"name": "Ravi", "marks": 92},
    {"name": "Kiran", "marks": 68},
    {"name": "Meena", "marks": 85},
    {"name": "Ajay", "marks": 48},
    {"name": "Sneha", "marks": 79},
    {"name": "Rahul", "marks": 95}
]
list(map(lambda student: student["marks"],filter(lambda student: student["marks"] > 70, students)))
# Out:
# [92, 85, 79, 95]

# %% [markdown]
# Question 16

# %%
## Using filter(), map(), and reduce():
## Extract products currently in stock.
## Calculate each product's inventory value using price × stock.
## Calculate the total inventory value.
products = [
    {"name": "Laptop", "price": 55000, "stock": 5},
    {"name": "Mouse", "price": 600, "stock": 25},
    {"name": "Keyboard", "price": 1500, "stock": 0},
    {"name": "Monitor", "price": 18000, "stock": 8},
    {"name": "Printer", "price": 12000, "stock": 0},
    {"name": "SSD", "price": 6500, "stock": 12}
]
list(map(lambda product: product["price"] * product["stock"],filter(lambda product: product["stock"] > 0, products)))
# Out:
# [275000, 15000, 144000, 78000]

# %% [markdown]
# Question 17

# %%
## Using filter(), map(), and reduce():
## Extract products belonging to the Electronics category.
## Apply a 20% discount.
## Calculate the total discounted value.
products = [
    {"name": "Laptop", "price": 55000, "category": "Electronics"},
    {"name": "Chair", "price": 4500, "category": "Furniture"},
    {"name": "Monitor", "price": 18000, "category": "Electronics"},
    {"name": "Desk", "price": 8500, "category": "Furniture"},
    {"name": "SSD", "price": 6500, "category": "Electronics"}
]
list(map(lambda product: product["price"] - (product["price"] * 20 / 100),filter(lambda product: product["category"] == "Electronics", products)))
# Out:
# [44000.0, 14400.0, 5200.0]

# %% [markdown]
# Question 18

# %%
## Using filter() and reduce():
## Extract delivered orders.
## Calculate the total delivered revenue.
orders = [
    {"order_id": 1001, "amount": 1200, "status": "Delivered"},
    {"order_id": 1002, "amount": 3500, "status": "Pending"},
    {"order_id": 1003, "amount": 8500, "status": "Delivered"},
    {"order_id": 1004, "amount": 4200, "status": "Cancelled"},
    {"order_id": 1005, "amount": 7600, "status": "Delivered"},
    {"order_id": 1006, "amount": 5100, "status": "Pending"}
]
reduce(lambda total, order: total + order["amount"],filter(lambda order: order["status"] == "Delivered", orders),0)
# Out:
# 17300

# %% [markdown]
# Question 19

# %%
## Using filter(), map(), and reduce():
## Extract transactions whose amount is greater than 5000.
## Add 18% GST to every selected transaction.
## Calculate the grand total after GST.
transactions = [
    {"id": 1, "amount": 1200},
    {"id": 2, "amount": 5200},
    {"id": 3, "amount": 18000},
    {"id": 4, "amount": 2500},
    {"id": 5, "amount": 9600},
    {"id": 6, "amount": 7200}
]
list(map(lambda transaction: transaction["amount"] + (transaction["amount"] * 18 / 100),filter(lambda transaction: transaction["amount"] > 5000, transactions)))
# Out:
# [6136.0, 21240.0, 11328.0, 8496.0]

# %% [markdown]
# Question 20

# %%
## Using filter(), map(), and reduce():
## Extract active salespeople from the South region.
## Calculate a 5% incentive for each selected salesperson.
## Create a list containing salesperson name, sales amount, and incentive.
## Calculate the total incentive payable.
sales_records = [
    {"salesperson": "Rahul", "region": "South", "sales": 45000, "active": True},
    {"salesperson": "Anil", "region": "North", "sales": 65000, "active": True},
    {"salesperson": "Sneha", "region": "South", "sales": 72000, "active": False},
    {"salesperson": "Kiran", "region": "South", "sales": 82000, "active": True},
    {"salesperson": "Meena", "region": "West", "sales": 55000, "active": True},
    {"salesperson": "Arjun", "region": "South", "sales": 98000, "active": True}
]
selected = filter(lambda s: s["region"] == "South" and s["active"],sales_records)

result = list(map(lambda s: {"salesperson": s["salesperson"],"sales": s["sales"],"incentive": s["sales"] * 0.05},selected))

total = reduce(lambda a, b: a + b["incentive"], result, 0)

print(result)
print(total)
# Out:
# [{'salesperson': 'Rahul', 'sales': 45000, 'incentive': 2250.0}, {'salesperson': 'Kiran', 'sales': 82000, 'incentive': 4100.0}, {'salesperson': 'Arjun', 'sales': 98000, 'incentive': 4900.0}]
# 11250.0
